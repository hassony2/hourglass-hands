-- %%
projectDir = paths.concat('/home/local/yhasson/baselines/tzionas/pose-hg-train')

-- %%
paths.dofile(projectDir .. '/src/ref.lua')
-- Out:
-- /home/local/yhasson/datasets/tzionas/15/1
-- Saving everything to: /home/local/yhasson/baselines/tzionas/pose-hg-train/exp/tzionas/default
-- Found Environment variable CUDNN_PATH = /home/ROCQ/willow/yhasson/lib/libcudnn.so.5
-- Input is a tensor with dimensions: 3 x 256 x 256
-- Output is a table
-- 	 Entry 1 is a tensor with dimensions: 28 x 64 x 64
-- 	 Entry 2 is a tensor with dimensions: 28 x 64 x 64
-- 	 Entry 3 is a tensor with dimensions: 28 x 64 x 64
-- 	 Entry 4 is a tensor with dimensions: 28 x 64 x 64
-- 	 Entry 5 is a tensor with dimensions: 28 x 64 x 64
-- 	 Entry 6 is a tensor with dimensions: 28 x 64 x 64
-- 	 Entry 7 is a tensor with dimensions: 28 x 64 x 64
-- 	 Entry 8 is a tensor with dimensions: 28 x 64 x 64
-- # of training images:	27
-- # of validation images:	6

-- %%
local set = 'train'
local tmpIdx = opt.idxRef[set][torch.random(dataset:size(set))]
tmpIdx = 100
print(tmpIdx)
inp,hms = heatmapVisualization(set,tmpIdx)
itorch.image(inp)
itorch.image(hms)
-- Out:
-- 100
-- got file!
-- Console does not support images
-- Console does not support images
